# %% [markdown]
# # Pneumonia Classification

# %% [markdown]
# * Original image shape 1024x1024 -> 224x224
# * Standardize to [0,1] (1/255)
# * 24000 to training and 2684 to validation
# * 0 if no pneumonia 1 if pneumonia

# %%
from pathlib import Path
import pydicom
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import os

# %matplotlib inline

# %%
#Reading the csv file

#MODIFICAR RUTA, NO CONFUNDIR TRABAJO LOCAL VS COLAB
labels = pd.read_csv('stage_2_train_labels.csv')

# %%
labels.head(10)
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# 5  00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0       1
# 6  00569f44-917d-4c86-a842-81832af98c30    NaN    NaN    NaN     NaN       0
# 7  006cec2e-6ce2-4549-bffa-eadfcd1e9970    NaN    NaN    NaN     NaN       0
# 8  00704310-78a8-4b38-8475-49f4573b2dbb  323.0  577.0  160.0   104.0       1
# 9  00704310-78a8-4b38-8475-49f4573b2dbb  695.0  575.0  162.0   137.0       1

# %%
# Remove duplicate
labels = labels.drop_duplicates("patientId")
labels.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %% [markdown]
# Dicom file paths and npy files

# %%
train_images_path = Path('stage_2_train_images')
save_path = Path('Processed')

# %%
#Verificamos que toda imagen de entrenamiento tiene anotacion
import glob
patient_ids = labels['patientId'].to_numpy()
train_ids =  glob.glob(os.path.join("stage_2_train_images", '*.dcm'))
ids = []
for i in train_ids:
  ids.append(i.split('/')[-1][:-4])

ids_array = np.array(ids)

patient_ids = set(patient_ids)
ids_array = set(ids_array)

inter = list(patient_ids.intersection(ids_array))
len(inter)
# Out:
# 11119

# %% [markdown]
# Example images

# %%
fig, axis = plt.subplots(3, 3, figsize=(9, 9))
dcm_paths = train_ids[45:55]
c = 0
for i in range(3):
    for j in range(3):
        patient_id = labels.patientId.iloc[c]
        dcm_path = train_images_path/patient_id
        dcm_path = dcm_path.with_suffix(".dcm")
        dcm = pydicom.read_file(dcm_paths[c]).pixel_array

        label = labels.loc[labels['patientId'] == dcm_paths[c].split('/')[-1][:-4], 'Target'].values[0]

        axis[i][j].imshow(dcm, cmap="bone")
        axis[i][j].set_title(label)
        axis[i][j].set_axis_off()
        c+=1

# %% [markdown]
# ## Dicom Reading & Effective storage
#
# In order to efficiently handle our data in the Dataloader, we convert the X-Ray images stored in the DICOM format to numpy arrays. Afterwards we compute the overall mean and standard deviation of the pixels of the whole dataset, for the purpose of normalization.
# Then the created numpy images are stored in two separate folders according to their binary label:
# * 0: All X-Rays which do not show signs of pneumonia
# * 1: All X-Rays which show signs of pneumonia

# %% [markdown]
# To do so, we iterate over the patient ids and concat the patient ID with the ROOT_PATH.
#
# We then directly save the standardized and resized files into the corresponding directory (0 for healthy, 1 for pneumonia).
# This allows to take advantage of the ready-to-use torchvision **DatasetFolder** for simple file reading
#
#
# We standardize all images by the maximum pixel value in the provided dataset, 255.
# All images are resized to 224x224.
#
# To compute dataset mean and standard deviation, we compute the sum of the pixel values as well as the sum of the squared pixel values for each subject.
# This allows to compute the overall mean and standard deviation without keeping the whole dataset in memory.

# %%
sums, sums_squared = 0, 0

for c, patient_id in enumerate(tqdm(train_ids)):
    dcm_path = patient_id

    # Read the dicom file with pydicom and standardize the array
    dcm = pydicom.read_file(dcm_path).pixel_array/255

    # Resize to 224x224 and convert to float16 to reduce the storing space
    dcm_array = cv2.resize(dcm,(224,224)).astype(np.float16)

    # Retrieve the corresponding label
    label = labels.loc[labels['patientId'] == dcm_path.split('\\')[-1][:-4], 'Target'].values[0]

    # Train (4/5) or validate (1/5)
    train_or_val = 'train' if c <8900 else 'val'

    current_save_path = save_path/train_or_val/str(label) # Define save path and create if necessary
    current_save_path.mkdir(parents=True, exist_ok=True)
    np.save(current_save_path/patient_id.split('\\')[-1][:-4], dcm_array)     # Save the array in the corresponding directory

    normalizer = dcm_array.shape[0]*dcm_array.shape[1]
    if train_or_val == 'train':
        sums += np.sum(dcm_array)/normalizer
        sums_squared += (np.power(dcm_array, 2).sum())/normalizer
# Out:
#   0%|          | 0/26684 [00:00<?, ?it/s]

# %%
mean = sums/8900
std = np.sqrt((sums_squared/8900)-mean**2)

# %%
mean, std
# Out:
# (0.4903962485384803, 0.24795070634161256)

# %% [markdown]
# ## Train 01 - Data Loading

# %%
# %pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.1.2-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: numpy>=1.17.2 in /home/dlmanrique/anaconda3/envs/st2/lib/python3.12/site-packages (from pytorch_lightning) (1.26.2)
# INFO: pip is looking at multiple versions of pytorch-lightning to determine which version is compatible with other requirements. This could take a while.
#   Downloading pytorch_lightning-2.1.1-py3-none-any.whl.metadata (21 kB)
#   Downloading pytorch_lightning-2.1.0-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.9.post0-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.9-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.8-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.7-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.6-py3-none-any.whl.metadata (23 kB)
# INFO: pip is still looking at multiple versions of pytorch-lightning to determine which version is compatible with other requirements. This could take a while.
#   Downloading pytorch_lightning-2.0.5-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.4-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.3-py3-none-any.whl.metadata (23 kB)
#   Downloading pytorch_lightning-2.0.2-py3-none-any.whl (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 36.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-2.0.1.post0-py3-none-any.whl (718 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.6/718.6 kB 43.1 MB/s eta 0:00:00
# INFO: This is taking longer than usual. You might need to provide the dependency resolver with stricter constraints to reduce runtime. See https://pip.pypa.io/warnings/backtracking for guidance. If you want to abort this run, press Ctrl + C.
#   Downloading pytorch_lightning-2.0.1-py3-none-any.whl (716 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.4/716.4 kB 40.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-2.0.0-py3-none-any.whl (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.6/715.6 kB 45.9 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 51.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 42.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.9.3-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.4/826.4 kB 42.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.9.2-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.2/826.2 kB 49.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.9.1-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 41.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.9.0-py3-none-any.whl (825 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 46.9 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.6-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 kB 43.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.5.post0-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 48.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.5-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.4/800.4 kB 50.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.4.post0-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 kB 40.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.4-py3-none-any.whl (799 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.0/800.0 kB 42.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.3.post2-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 35.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.3.post1-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 45.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.3.post0-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.0/799.0 kB 47.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.3-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 49.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.2-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.7/798.7 kB 44.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.1-py3-none-any.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.4/798.4 kB 45.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.0.post1-py3-none-any.whl (796 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.1/796.1 kB 46.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.8.0-py3-none-any.whl (795 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.8/795.8 kB 42.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 kB 47.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.6-py3-none-any.whl (707 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 707.5/707.5 kB 47.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.5-py3-none-any.whl (706 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.6/706.6 kB 45.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.4-py3-none-any.whl (706 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.5/706.5 kB 43.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.3-py3-none-any.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.8/705.8 kB 45.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.2-py3-none-any.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.6/705.6 kB 41.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.1-py3-none-any.whl (701 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.5/701.5 kB 41.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.7.0-py3-none-any.whl (700 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 700.9/700.9 kB 47.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.6.5-py3-none-any.whl (585 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.9/585.9 kB 42.0 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 585.5/585.5 kB 34.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.6.3-py3-none-any.whl (584 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.0/584.0 kB 41.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.6.2-py3-none-any.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.9/582.9 kB 36.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.6.1-py3-none-any.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.5/582.5 kB 44.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.6.0-py3-none-any.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.1/582.1 kB 43.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.10-py3-none-any.whl (527 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.7/527.7 kB 34.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.9-py3-none-any.whl (527 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.2/527.2 kB 31.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.8-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.5/526.5 kB 37.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.7-py3-none-any.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.2/526.2 kB 42.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.6-py3-none-any.whl (525 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.4/525.4 kB 41.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.5-py3-none-any.whl (525 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.1/525.1 kB 40.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.4-py3-none-any.whl (524 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 kB 34.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.3-py3-none-any.whl (523 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 523.4/523.4 kB 34.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.2-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.1-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.5.0-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.9-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.8/925.8 kB 54.9 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.8-py3-none-any.whl (924 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.0/924.0 kB 54.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.7-py3-none-any.whl (923 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 923.7/923.7 kB 44.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.6-py3-none-any.whl (922 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.5/922.5 kB 53.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.5-py3-none-any.whl (919 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 919.2/919.2 kB 54.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.4-py3-none-any.whl (918 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 918.4/918.4 kB 45.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.3-py3-none-any.whl (918 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 918.4/918.4 kB 45.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.2-py3-none-any.whl (916 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 916.6/916.6 kB 53.9 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.1-py3-none-any.whl (915 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.1/915.1 kB 54.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.4.0-py3-none-any.whl (913 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.2/913.2 kB 42.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.8-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.4/813.4 kB 42.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.7.post0-py3-none-any.whl (810 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.9/810.9 kB 46.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.7-py3-none-any.whl (810 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.7/810.7 kB 41.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.6-py3-none-any.whl (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.2/809.2 kB 48.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.5-py3-none-any.whl (808 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.6/808.6 kB 41.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.4-py3-none-any.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.4/806.4 kB 37.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.3-py3-none-any.whl (806 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.2/806.2 kB 49.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.2-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.7/805.7 kB 49.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.1-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.1/805.1 kB 43.9 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.3.0-py3-none-any.whl (804 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.4/804.4 kB 50.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.10-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.9/841.9 kB 50.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.9-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.9/841.9 kB 52.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.8-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.9/841.9 kB 40.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.7-py3-none-any.whl (830 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.7/830.7 kB 45.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.6-py3-none-any.whl (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.6/829.6 kB 47.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.5-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.1/826.1 kB 45.3 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.4-py3-none-any.whl (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.1/829.1 kB 47.0 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.3-py3-none-any.whl (821 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.9/821.9 kB 51.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.2-py3-none-any.whl (816 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.5/816.5 kB 41.9 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.1-py3-none-any.whl (814 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 814.2/814.2 kB 28.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.2.0-py3-none-any.whl (813 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 35.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.8-py3-none-any.whl (696 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 696.1/696.1 kB 43.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.7-py3-none-any.whl (695 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 695.2/695.2 kB 48.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.6-py3-none-any.whl (687 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.9/687.9 kB 37.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.5-py3-none-any.whl (685 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 685.5/685.5 kB 45.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.4-py3-none-any.whl (684 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 684.0/684.0 kB 47.0 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.3-py3-none-any.whl (680 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.7/680.7 kB 45.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.2-py3-none-any.whl (671 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.6/671.6 kB 45.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.1-py3-none-any.whl (669 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 669.7/669.7 kB 41.0 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.1.0-py3-none-any.whl (665 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 665.6/665.6 kB 40.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.8-py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 41.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.7-py3-none-any.whl (557 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.2/557.2 kB 42.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.6-py3-none-any.whl (548 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.3/548.3 kB 40.0 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.5-py3-none-any.whl (559 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.4/559.4 kB 34.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.4-py3-none-any.whl (554 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.3/554.3 kB 39.6 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.3-py3-none-any.whl (533 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.9/533.9 kB 36.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.2-py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 33.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.1-py3-none-any.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.5/511.5 kB 37.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-1.0.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.4/510.4 kB 35.8 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.10.0-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.7/471.7 kB 34.2 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.9.0-py3-none-any.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.2/408.2 kB 34.1 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.8.5-py3-none-any.whl (313 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.0/313.0 kB 26.5 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.8.4-py3-none-any.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.7/304.7 kB 27.7 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.8.3-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.1/302.1 kB 27.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.41.0 in /home/dlmanrique/anaconda3/envs/st2/lib/python3.12/site-packages (from pytorch_lightning) (4.66.1)
#   Downloading pytorch_lightning-0.8.1-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.1/293.1 kB 19.4 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.7.6-py3-none-any.whl (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 23.0 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.7.5-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 19.0 MB/s eta 0:00:00
#   Downloading pytorch_lightning-0.7.3-py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.2/203.2 kB 15.4 MB/s eta 0:00:00
#   Downloading pytorch-lightning-0.7.1.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 3.1 MB/s eta 0:00:0000:0100:01m
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.6.0.tar.gz (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn>=0.20.2 (from pytorch_lightning)
#   Downloading scikit_learn-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pytorch_lightning
#   Downloading pytorch-lightning-0.5.3.3.tar.gz (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.5.3.2.tar.gz (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn==0.20.2 (from pytorch_lightning)
#   Downloading scikit-learn-0.20.2.tar.gz (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 3.4 MB/s eta 0:00:0000:010:01m
#   Preparing metadata (setup.py) ... done
# Collecting tqdm==4.35.0 (from pytorch_lightning)
#   Downloading tqdm-4.35.0-py2.py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 5.1 MB/s eta 0:00:00
# Collecting numpy==1.16.4 (from pytorch_lightning)
#   Downloading numpy-1.16.4.zip (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 13.6 MB/s eta 0:00:0000:0100:01m
#   Preparing metadata (setup.py) ... done
# Collecting pytorch_lightning
#   Downloading pytorch-lightning-0.5.3.1.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting twine==1.13.0 (from pytorch_lightning)
#   Downloading twine-1.13.0-py2.py3-none-any.whl (34 kB)
# Collecting pytorch_lightning
#   Downloading pytorch-lightning-0.5.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.5.2.1.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.5.2.tar.gz (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.5.1.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.5.1.2.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.5.1.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.5.0.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.9.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.8.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.7.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.6.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.5.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.4.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.3.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.2.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.1.tar.gz (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.4.0.tar.gz (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.9.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.8/369.8 kB 20.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.8.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.6/369.6 kB 25.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.7.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.5/369.5 kB 23.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.6.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.5/369.5 kB 21.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.5.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.5/369.5 kB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.4.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.6/369.6 kB 24.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.3.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.6/369.6 kB 22.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.1.tar.gz (370 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.5/370.5 kB 30.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.6.tar.gz (369 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.9/369.9 kB 29.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.5.tar.gz (368 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 368.5/368.5 kB 25.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.4.1.tar.gz (359 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.4/359.4 kB 25.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.4.tar.gz (359 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.3/359.3 kB 24.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.3.tar.gz (359 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.2/359.2 kB 25.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.2.tar.gz (359 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.1/359.1 kB 23.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.1.tar.gz (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.2/358.2 kB 24.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.3.tar.gz (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.8/357.8 kB 24.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.6.tar.gz (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.8/357.8 kB 23.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.5.2.tar.gz (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.7/357.7 kB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.5.1.tar.gz (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.6/357.6 kB 24.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.5.tar.gz (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.4/357.4 kB 21.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.4.1.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.5/356.5 kB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.4.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.5/356.5 kB 24.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.3.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.4/356.4 kB 17.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.2.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.9/356.9 kB 22.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.2.tar.gz (356 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 356.5/356.5 kB 21.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Downloading pytorch-lightning-0.0.2.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting test-tube (from pytorch_lightning)
#   Downloading test_tube-0.7.5.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# ERROR: Cannot install pytorch-lightning==0.0.2, pytorch-lightning==0.10.0, pytorch-lightning==0.2, pytorch-lightning==0.2.2, pytorch-lightning==0.2.3, pytorch-lightning==0.2.4, pytorch-lightning==0.2.4.1, pytorch-lightning==0.2.5, pytorch-lightning==0.2.5.1, pytorch-lightning==0.2.5.2, pytorch-lightning==0.2.6, pytorch-lightning==0.3, pytorch-lightning==0.3.1, pytorch-lightning==0.3.2, pytorch-lightning==0.3.3, pytorch-lightning==0.3.4, pytorch-lightning==0.3.4.1, pytorch-lightning==0.3.5, pytorch-lightning==0.3.6, pytorch-lightning==0.3.6.1, pytorch-lightning==0.3.6.3, pytorch-lightning==0.3.6.4, pytorch-lightning==0.3.6.5, pytorch-lightning==0.3.6.6, pytorch-lightning==0.3.6.7, pytorch-lightning==0.3.6.8, pytorch-lightning==0.3.6.9, pytorch-lightning==0.4.0, pytorch-lightning==0.4.1, pytorch-lightning==0.4.2, pytorch-lightning==0.4.3, pytorch-lightning==0.4.4, pytorch-lightning==0.4.5, pytorch-lightning==0.4.6, pytorch-lightning==0.4.7, pytorch-lightning==0.4.8, pytorch-lightning==0.4.9, pytorch-lightning==0.5.0, pytorch-lightning==0.5.1, pytorch-lightning==0.5.1.2, pytorch-lightning==0.5.1.3, pytorch-lightning==0.5.2, pytorch-lightning==0.5.2.1, pytorch-lightning==0.5.3, pytorch-lightning==0.5.3.1, pytorch-lightning==0.5.3.2, pytorch-lightning==0.5.3.3, pytorch-lightning==0.6.0, pytorch-lightning==0.7.1, pytorch-lightning==0.7.3, pytorch-lightning==0.7.5, pytorch-lightning==0.7.6, pytorch-lightning==0.8.1, pytorch-lightning==0.8.3, pytorch-lightning==0.8.4, pytorch-lightning==0.8.5, pytorch-lightning==0.9.0, pytorch-lightning==1.0.0, pytorch-lightning==1.0.1, pytorch-lightning==1.0.2, pytorch-lightning==1.0.3, pytorch-lightning==1.0.4, pytorch-lightning==1.0.5, pytorch-lightning==1.0.6, pytorch-lightning==1.0.7, pytorch-lightning==1.0.8, pytorch-lightning==1.1.0, pytorch-lightning==1.1.1, pytorch-lightning==1.1.2, pytorch-lightning==1.1.3, pytorch-lightning==1.1.4, pytorch-lightning==1.1.5, pytorch-lightning==1.1.6, pytorch-lightning==1.1.7, pytorch-lightning==1.1.8, pytorch-lightning==1.2.0, pytorch-lightning==1.2.1, pytorch-lightning==1.2.10, pytorch-lightning==1.2.2, pytorch-lightning==1.2.3, pytorch-lightning==1.2.4, pytorch-lightning==1.2.5, pytorch-lightning==1.2.6, pytorch-lightning==1.2.7, pytorch-lightning==1.2.8, pytorch-lightning==1.2.9, pytorch-lightning==1.3.0, pytorch-lightning==1.3.1, pytorch-lightning==1.3.2, pytorch-lightning==1.3.3, pytorch-lightning==1.3.4, pytorch-lightning==1.3.5, pytorch-lightning==1.3.6, pytorch-lightning==1.3.7, pytorch-lightning==1.3.7.post0, pytorch-lightning==1.3.8, pytorch-lightning==1.4.0, pytorch-lightning==1.4.1, pytorch-lightning==1.4.2, pytorch-lightning==1.4.3, pytorch-lightning==1.4.4, pytorch-lightning==1.4.5, pytorch-lightning==1.4.6, pytorch-lightning==1.4.7, pytorch-lightning==1.4.8, pytorch-lightning==1.4.9, pytorch-lightning==1.5.0, pytorch-lightning==1.5.1, pytorch-lightning==1.5.10, pytorch-lightning==1.5.2, pytorch-lightning==1.5.3, pytorch-lightning==1.5.4, pytorch-lightning==1.5.5, pytorch-lightning==1.5.6, pytorch-lightning==1.5.7, pytorch-lightning==1.5.8, pytorch-lightning==1.5.9, pytorch-lightning==1.6.0, pytorch-lightning==1.6.1, pytorch-lightning==1.6.2, pytorch-lightning==1.6.3, pytorch-lightning==1.6.4, pytorch-lightning==1.6.5, pytorch-lightning==1.7.0, pytorch-lightning==1.7.1, pytorch-lightning==1.7.2, pytorch-lightning==1.7.3, pytorch-lightning==1.7.4, pytorch-lightning==1.7.5, pytorch-lightning==1.7.6, pytorch-lightning==1.7.7, pytorch-lightning==1.8.0, pytorch-lightning==1.8.0.post1, pytorch-lightning==1.8.1, pytorch-lightning==1.8.2, pytorch-lightning==1.8.3, pytorch-lightning==1.8.3.post0, pytorch-lightning==1.8.3.post1, pytorch-lightning==1.8.3.post2, pytorch-lightning==1.8.4, pytorch-lightning==1.8.4.post0, pytorch-lightning==1.8.5, pytorch-lightning==1.8.5.post0, pytorch-lightning==1.8.6, pytorch-lightning==1.9.0, pytorch-lightning==1.9.1, pytorch-lightning==1.9.2, pytorch-lightning==1.9.3, pytorch-lightning==1.9.4, pytorch-lightning==1.9.5, p ...
#
# The conflict is caused by:
#     pytorch-lightning 2.1.2 depends on torch>=1.12.0
#     pytorch-lightning 2.1.1 depends on torch>=1.12.0
#     pytorch-lightning 2.1.0 depends on torch>=1.12.0
#     pytorch-lightning 2.0.9.post0 depends on torch>=1.11.0
#     pytorch-lightning 2.0.9 depends on torch>=1.11.0
#     pytorch-lightning 2.0.8 depends on torch>=1.11.0
#     pytorch-lightning 2.0.7 depends on torch>=1.11.0
#     pytorch-lightning 2.0.6 depends on torch>=1.11.0
#     pytorch-lightning 2.0.5 depends on torch>=1.11.0
#     pytorch-lightning 2.0.4 depends on torch>=1.11.0
#     pytorch-lightning 2.0.3 depends on torch>=1.11.0
#     pytorch-lightning 2.0.2 depends on torch>=1.11.0
#     pytorch-lightning 2.0.1.post0 depends on torch>=1.11.0
#     pytorch-lightning 2.0.1 depends on torch>=1.11.0
#     pytorch-lightning 2.0.0 depends on torch>=1.11.0
#     pytorch-lightning 1.9.5 depends on torch>=1.10.0
#     pytorch-lightning 1.9.4 depends on torch>=1.10.0
#     pytorch-lightning 1.9.3 depends on torch>=1.10.0
#     pytorch-lightning 1.9.2 depends on torch>=1.10.0
#     pytorch-lightning 1.9.1 depends on torch>=1.10.0
#     pytorch-lightning 1.9.0 depends on torch>=1.10.0
#     pytorch-lightning 1.8.6 depends on torch>=1.9.0
#     pytorch-lightning 1.8.5.post0 depends on torch>=1.9.0
#     pytorch-lightning 1.8.5 depends on torch>=1.9.0
#     pytorch-lightning 1.8.4.post0 depends on torch>=1.9.0
#     pytorch-lightning 1.8.4 depends on torch>=1.9.0
#     pytorch-lightning 1.8.3.post2 depends on torch>=1.9.*
#     pytorch-lightning 1.8.3.post1 depends on torch>=1.9.*
#     pytorch-lightning 1.8.3.post0 depends on torch>=1.9.*
#     pytorch-lightning 1.8.3 depends on torch>=1.9.*
#     pytorch-lightning 1.8.2 depends on torch>=1.9.*
#     pytorch-lightning 1.8.1 depends on torch>=1.9.*
#     pytorch-lightning 1.8.0.post1 depends on torch>=1.9.*
#     pytorch-lightning 1.8.0 depends on torch>=1.9.*
#     pytorch-lightning 1.7.7 depends on torch>=1.9.*
#     pytorch-lightning 1.7.6 depends on torch>=1.9.*
#     pytorch-lightning 1.7.5 depends on torch>=1.9.*
#     pytorch-lightning 1.7.4 depends on torch>=1.9.*
#     pytorch-lightning 1.7.3 depends on torch>=1.9.*
#     pytorch-lightning 1.7.2 depends on torch>=1.9.*
#     pytorch-lightning 1.7.1 depends on torch>=1.9.*
#     pytorch-lightning 1.7.0 depends on torch>=1.9.*
#     pytorch-lightning 1.6.5 depends on torch>=1.8.*
#     pytorch-lightning 1.6.4 depends on torch>=1.8.*
#     pytorch-lightning 1.6.3 depends on torch>=1.8.*
#     pytorch-lightning 1.6.2 depends on torch>=1.8.*
#     pytorch-lightning 1.6.1 depends on torch>=1.8.*
#     pytorch-lightning 1.6.0 depends on torch>=1.8.*
#     pytorch-lightning 1.5.10 depends on torch>=1.7.*
#     pytorch-lightning 1.5.9 depends on torch>=1.7.*
#     pytorch-lightning 1.5.8 depends on torch>=1.7.*
#     pytorch-lightning 1.5.7 depends on torch>=1.7.*
#     pytorch-lightning 1.5.6 depends on torch>=1.7.*
#     pytorch-lightning 1.5.5 depends on torch>=1.7.*
#     pytorch-lightning 1.5.4 depends on torch>=1.7.*
#     pytorch-lightning 1.5.3 depends on torch>=1.6
#     pytorch-lightning 1.5.2 depends on torch>=1.6
#     pytorch-lightning 1.5.1 depends on torch>=1.6
#     pytorch-lightning 1.5.0 depends on torch>=1.6
#     pytorch-lightning 1.4.9 depends on torch>=1.6
#     pytorch-lightning 1.4.8 depends on torch>=1.6
#     pytorch-lightning 1.4.7 depends on torch>=1.6
#     pytorch-lightning 1.4.6 depends on torch>=1.6
#     pytorch-lightning 1.4.5 depends on torch>=1.6
#     pytorch-lightning 1.4.4 depends on torch>=1.6
#     pytorch-lightning 1.4.3 depends on torch>=1.6
#     pytorch-lightning 1.4.2 depends on torch>=1.6
#     pytorch-lightning 1.4.1 depends on torch>=1.6
#     pytorch-lightning 1.4.0 depends on torch>=1.6
#     pytorch-lightning 1.3.8 depends on torch>=1.4
#     pytorch-lightning 1.3.7.post0 depends on torch>=1.4
#     pytorch-lightning 1.3.7 depends on torch>=1.4
#     pytorch-lightning 1.3.6 depends on torch>=1.4
#     pytorch-lightning 1.3.5 depends on torch>=1.4
#     pytorch-lightning 1.3.4 depends on torch>=1.4
#     pytorch-lightning 1.3.3 depends on torch>=1.4
#     pytorch-lightning 1.3.2 depends on torch>=1.4
#     pytorch-lightning 1.3.1 depends on torch>=1.4
#     pytorch-lightning 1.3.0 depends on torch>=1.4
#     pytorch-lightning 1.2.10 depends on torch>=1.4
#     pytorch-lightning 1.2.9 depends on torch>=1.4
#     pytorch-lightning 1.2.8 depends on torch>=1.4
#     pytorch-lightning 1.2.7 depends on torch>=1.4
#     pytorch-lightning 1.2.6 depends on torch>=1.4
#     pytorch-lightning 1.2.5 depends on torch>=1.4
#     pytorch-lightning 1.2.4 depends on torch>=1.4
#     pytorch-lightning 1.2.3 depends on torch>=1.4
#     pytorch-lightning 1.2.2 depends on torch>=1.4
#     pytorch-lightning 1.2.1 depends on torch>=1.4
#     pytorch-lightning 1.2.0 depends on torch>=1.4
#     pytorch-lightning 1.1.8 depends on torch>=1.3
#     pytorch-lightning 1.1.7 depends on torch>=1.3
#     pytorch-lightning 1.1.6 depends on torch>=1.3
#     pytorch-lightning 1.1.5 depends on torch>=1.3
#     pytorch-lightning 1.1.4 depends on torch>=1.3
#     pytorch-lightning 1.1.3 depends on torch>=1.3
#     pytorch-lightning 1.1.2 depends on torch>=1.3
#     pytorch-lightning 1.1.1 depends on torch>=1.3
#     pytorch-lightning 1.1.0 depends on torch>=1.3
#     pytorch-lightning 1.0.8 depends on torch>=1.3
#     pytorch-lightning 1.0.7 depends on torch>=1.3
#     pytorch-lightning 1.0.6 depends on torch>=1.3
#     pytorch-lightning 1.0.5 depends on torch<1.8 and >=1.3
#     pytorch-lightning 1.0.4 depends on torch>=1.3
#     pytorch-lightning 1.0.3 depends on torch>=1.3
#     pytorch-lightning 1.0.2 depends on torch>=1.3
#     pytorch-lightning 1.0.1 depends on torch>=1.3
#     pytorch-lightning 1.0.0 depends on torch>=1.3
#     pytorch-lightning 0.10.0 depends on torch>=1.3
#     pytorch-lightning 0.9.0 depends on torch>=1.3
#     pytorch-lightning 0.8.5 depends on torch>=1.3
#     pytorch-lightning 0.8.4 depends on torch>=1.3
#     pytorch-lightning 0.8.3 depends on torch>=1.3
#     pytorch-lightning 0.8.1 depends on torch>=1.3
#     pytorch-lightning 0.7.6 depends on torch>=1.1
#     pytorch-lightning 0.7.5 depends on torch>=1.1
#     pytorch-lightning 0.7.3 depends on torch>=1.1
#     pytorch-lightning 0.7.1 depends on torch>=1.1
#     pytorch-lightning 0.6.0 depends on torch>=1.1
#     pytorch-lightning 0.5.3.3 depends on torch>=1.1
#     pytorch-lightning 0.5.3.2 depends on torch>=1.2.0
#     pytorch-lightning 0.5.3.1 depends on torch>=1.2.0
#     pytorch-lightning 0.5.3 depends on torch>=1.2.0
#     pytorch-lightning 0.5.2.1 depends on torch>=1.2.0
#     pytorch-lightning 0.5.2 depends on torch>=1.2.0
#     pytorch-lightning 0.5.1.3 depends on torch>=1.2.0
#     pytorch-lightning 0.5.1.2 depends on torch>=1.2.0
#     pytorch-lightning 0.5.1 depends on torch>=1.2.0
#     pytorch-lightning 0.5.0 depends on torch==1.2.0
#     pytorch-lightning 0.4.9 depends on torch==1.2.0
#     pytorch-lightning 0.4.8 depends on torch==1.2.0
#     pytorch-lightning 0.4.7 depends on torch==1.2.0
#     pytorch-lightning 0.4.6 depends on torch==1.2.0
#     pytorch-lightning 0.4.5 depends on torch==1.2.0
#     pytorch-lightning 0.4.4 depends on torch==1.2.0
#     pytorch-lightning 0.4.3 depends on torch==1.2.0
#     pytorch-lightning 0.4.2 depends on torch==1.2.0
#     pytorch-lightning 0.4.1 depends on torch==1.1.0
#     pytorch-lightning 0.4.0 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.9 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.8 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.7 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.6 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.5 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.4 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.3 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6.1 depends on torch>=1.1.0
#     pytorch-lightning 0.3.6 depends on torch>=1.1.0
#     pytorch-lightning 0.3.5 depends on torch>=1.1.0
#     pytorch-lightning 0.3.4.1 depends on torch>=1.1.0
#     pytorch-lightning 0.3.4 depends on torch>=1.1.0
#     pytorch-lightning 0.3.3 depends on torch>=1.1.0
#     pytorch-lightning 0.3.2 depends on torch>=1.1.0
#     pytorch-lightning 0.3.1 depends on torch>=1.1.0
#     pytorch-lightning 0.3 depends on torch>=1.1.0
#     pytorch-lightning 0.2.6 depends on torch>=1.1.0
#     pytorch-lightning 0.2.5.2 depends on torch>=1.1.0
#     pytorch-lightning 0.2.5.1 depends on torch>=1.1.0
#     pytorch-lightning 0.2.5 depends on torch>=1.1.0
#     pytorch-lightning 0.2.4.1 depends on torch>=1.1.0
#     pytorch-lightning 0.2.4 depends on torch>=1.1.0
#     pytorch-lightning 0.2.3 depends on torch>=1.1.0
#     pytorch-lightning 0.2.2 depends on torch>=1.1.0
#     pytorch-lightning 0.2 depends on torch>=1.1.0
#     pytorch-lightning 0.0.2 depends on torch
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
#
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torchvision
from torchvision import transforms
import torchmetrics
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# First we create our dataset.
# We can leverage the **DatasetFolder** from torchvision: It allows to simply pass a root directory and return return a dataset object with access to all files within the directory and the directory name as class label. <br />
# We only need to define a loader function, **load_file**, which defines how the files shall be loaded.
# This is very comfortable as we only have to load our previously stored numpy files.
# Additionally, we need to define a list of file extensions (just "npy" in our case).
#
# Finally we can pass a transformation sequence for Data Augmentation and Normalization.
#
# We use:
# * RandomResizedCrops which applies a random crop of the image and resizes it to the original image size (224x224)
# * Random Rotations between -5 and 5 degrees
# * Random Translation (max 5%)
# * Random Scaling (0.9-1.1 of original image size)

# %%
def load_file(path):
    return np.load(path).astype(np.float32)

# %%
s_mean, s_std = 0.49, 0.248

train_transforms = transforms.Compose([
                                    transforms.ToTensor(),  # Convert numpy array to tensor
                                    transforms.Normalize(s_mean, s_std),  # Use mean and std from preprocessing notebook
                                    transforms.RandomAffine( # Data Augmentation
                                        degrees=(-5, 5), translate=(0, 0.05), scale=(0.9, 1.1)),
                                        transforms.RandomResizedCrop((224, 224), scale=(0.35, 1))

])

val_transforms = transforms.Compose([
                                    transforms.ToTensor(),  # Convert numpy array to tensor
                                    transforms.Normalize([s_mean], [s_std]),  # Use mean and std from preprocessing notebook
])

# %%
train_dataset = torchvision.datasets.DatasetFolder(
    os.path.join("Processed", "train"),
    loader=load_file, extensions="npy", transform=train_transforms)

val_dataset = torchvision.datasets.DatasetFolder(
    os.path.join("Processed", "val"),
    loader=load_file, extensions="npy", transform=val_transforms)

# %%
batch_size = 64#TODO
num_workers = 2# TODO

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, num_workers=num_workers, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, num_workers=num_workers, shuffle=False)

print(f"There are {len(train_dataset)} train images and {len(val_dataset)} val images")
# Out:
# There are 8900 train images and 2219 val images

# %%
#How many samples we have from each class?
np.unique(train_dataset.targets, return_counts = True)
# Out:
# (array([0, 1]), array([7371, 1529]))

# %% [markdown]
# ## Train 02 - Model Creation

# %%
'''
Modificar capas de entrada (conv1) y de salida (fc) para ajustar a los datos
que serán ingresados al modelo
'''
torchvision.models.resnet18()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
class PneumoniaModel(pl.LightningModule):
    def __init__(self, weight=1):
        super().__init__()

        self.model = torchvision.models.resnet18()
        # change conv1 from 3 to 1 input channels
        self.model.conv1 = torch.nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
        # change out_feature of the last fully connected layer (called fc in resnet18) from 1000 to 1
        self.model.fc = torch.nn.Linear(in_features=512, out_features=1)

        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=1e-4)
        self.loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor([weight]))

        # simple accuracy computation
        self.train_acc = torchmetrics.Accuracy(task="binary")
        self.val_acc = torchmetrics.Accuracy(task="binary")

    def forward(self, data):
        pred = self.model(data)
        return pred

    def training_step(self, batch, batch_idx):
        x_ray, label = batch
        label = label.float()  # Convert label to float (just needed for loss computation)
        pred = self(x_ray)[:,0]  # Prediction: Make sure prediction and label have same shape
        loss = self.loss_fn(pred, label)  # Compute the loss

        # Log loss and batch accuracy
        self.log("Train Loss", loss)
        self.log("Step Train Acc", self.train_acc(torch.sigmoid(pred), label.int()))
        return loss


    def on_training_epoch_end(self, outs):
      # Use this hook to perform any necessary actions at the end of each training epoch.
      # You can access the outputs from the training step by using the `self.trainer` attribute.
      # For example, to access the losses from each training step:
        train_losses = [x['loss'] for x in self.trainer.logged_metrics]
        avg_train_loss = torch.stack(train_losses).mean()
        self.log('train_loss', avg_train_loss)


    def validation_step(self, batch, batch_idx):
        # Same steps as in the training_step
        x_ray, label = batch
        label = label.float()
        pred = self(x_ray)[:,0]  # make sure prediction and label have same shape

        loss = self.loss_fn(pred, label)

        # Log validation metrics
        self.log("Val Loss", loss)
        self.log("Step Val Acc", self.val_acc(torch.sigmoid(pred), label.int()))
        return loss

    def on_validation_epoch_end(self):
        self.log("Val Acc", self.val_acc.compute())

    def configure_optimizers(self):
        #Caution! You always need to return a list here (just pack your optimizer into one :))
        return [self.optimizer]

# %%
model = PneumoniaModel()

# %%
# Create the checkpoint callback
checkpoint_callback = ModelCheckpoint(
    monitor='Val Acc',
    save_top_k=10,
    mode='max')

# %% [markdown]
# Trainer documentation: https://pytorch-lightning.readthedocs.io/en/latest/common/trainer.html

# %%
# Create the trainer
# Change the gpus parameter to the number of available gpus on your system. Use 0 for CPU training

gpus = 1 #TODO
trainer = pl.Trainer(callbacks=checkpoint_callback,
                     max_epochs=20)
# Out:
# Trainer will use only 1 of 4 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=4)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, train_loader, val_loader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name      | Type              | Params
# ------------------------------------------------
# 0 | model     | ResNet            | 11.2 M
# 1 | loss_fn   | BCEWithLogitsLoss | 0
# 2 | train_acc | BinaryAccuracy    | 0
# 3 | val_acc   | BinaryAccuracy    | 0
# ------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.683    Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/140 [00:00<?, ?it/s]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 1:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 2:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 3:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 4:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 5:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 6:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 7:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 8:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 9:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 10:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 11:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 12:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 13:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 14:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 15:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 16:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 17:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 18:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 19:   0%|          | 0/140 [00:00<?, ?it/s, v_num=1]
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# /home/dlmanrique/anaconda3/envs/st/lib/python3.10/site-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# Epoch 19: 100%|██████████| 140/140 [00:16<00:00,  8.66it/s, v_num=1]
# `Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 19: 100%|██████████| 140/140 [00:16<00:00,  8.48it/s, v_num=1]
